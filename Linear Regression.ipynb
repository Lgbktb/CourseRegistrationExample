# %%
P = point([(1,4),(2,3),(4,5)])

# %%
def foo(P):
    
    n = len(P[0].xdata)
    xsum=0
    ysum=0
    xtimesysum =0
    xsquaredsum =0
    for i in range(0,n):
        xsum+=P[0].xdata[i]
        ysum+=P[0].ydata[i]
        xtimesysum+=(P[0].xdata[i])*P[0].ydata[i]
        xsquaredsum+=(P[0].xdata[i])**2
    xmean = xsum/n
    ymean = ysum/n
    
    aone = (n*xtimesysum-xsum*ysum)/(n*xsquaredsum-xsum**2)
    azero = ymean - aone*xmean
    return (azero+x*aone)

# %%
result = foo(P)
result
# Out:
# 0.42857142857142855*x + 3.0

# %%
P+plot(result,(0,7))
# Out:
# Graphics object consisting of 2 graphics primitives
